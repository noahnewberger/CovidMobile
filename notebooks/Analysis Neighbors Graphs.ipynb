# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sys
from state_cleaner import *
import datetime
import csv
from scipy import stats as st
import itertools
import re 
from datetime import datetime

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
os.chdir('../..')
os.chdir('CovidMobile')
os.getcwd()
# Out:
# 'C:\\Users\\Noah\\CovidMobile'

# %%
df = pd.read_csv('data/analysis_data_{}.csv'.format(str(datetime.now().date())))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-7b96fdc093ee> in <module>()
# ----> 1 df = pd.read_csv('data/analysis_data_{}.csv'.format(str(datetime.now().date())))
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1    FIPS        date  device_count  \
# 0           0             0  1001.0  2020-02-15          5708
# 1           1             1  1001.0  2020-02-16          5655
# 2           2             2  1001.0  2020-02-17          5429
# 3           3             3  1001.0  2020-02-18          5270
# 4           4             4  1001.0  2020-02-19          5546
#
#    completely_home_device_count  part_time_work_behavior_devices  \
# 0                          1152                              622
# 1                          1334                              582
# 2                          1119                              780
# 3                           892                             1033
# 4                           974                             1054
#
#    full_time_work_behavior_devices  leaving_home  pct_leaving_home  ...  \
# 0                              180          4556         79.817800  ...
# ...

# %%
df.columns.values
# Out:
# array(['Unnamed: 0', 'Unnamed: 0.1', 'FIPS', 'date', 'device_count',
#        'completely_home_device_count', 'part_time_work_behavior_devices',
#        'full_time_work_behavior_devices', 'leaving_home',
#        'pct_leaving_home', 'pct_social_distancing', 'county_x', 'state_x',
#        'latitude', 'longitude', 'amount_land', 'population',
#        'ln_population', 'perc_elderly', 'med_hh_income', 'per_cap_income',
#        'perc_white', 'perc_african_american', 'perc_asian',
#        'perc_native_american', 'perc_other_race', 'perc_employed',
#        'perc_unemployed', 'perc_self_employed_not_own',
#        'perc_self_employed_own', 'perc_unpaid_fam_workers',
#        'perc_private_employees', 'perc_private_non_profit',
#        'perc_govt_workers', 'state_abb_x', 'retail', 'food_drugs', 'park',
#        'transit', 'work', 'homes', 'POP_ESTIMATE_2018', 'N_POP_CHG_2018',
#        'Births_2018', 'Deaths_2018', 'NATURAL_INC_2018',
# ...

# %%
f, ax = plt.subplots(1,2,sharex=True,sharey=True,figsize=(15,8))
sns.violinplot(x='post_state_sah',y='pct_social_distancing',data=df, showfliers=False, ax=ax[0])
sns.violinplot(x='post_state_sah_neighborall',y='pct_social_distancing',data=df, showfliers=False,ax=ax[1])

# %%
f, ax = plt.subplots(1,2,sharex=True,sharey=True,figsize=(15,8))
sns.violinplot(x='post_state_sah',y='pct_leaving_home',data=df, showfliers=False, ax=ax[0])
sns.violinplot(x='post_state_sah_neighborall',y='pct_leaving_home',data=df, showfliers=False,ax=ax[1])
